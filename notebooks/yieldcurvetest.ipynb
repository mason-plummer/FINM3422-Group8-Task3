# %%
# Environment and Imports
import sys
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# NEED TO CHANGE THIS 
from yieldcurve import YieldCurve

print(sys.version)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 8
#       5 import matplotlib.pyplot as plt
#       7 # NEED TO CHANGE THIS
# ----> 8 from notebooks.yieldcurve import YieldCurve
#      10 print(sys.version)
#
# ModuleNotFoundError: No module named 'notebooks'

# %%
# input yield data 

maturities = [0.25, 0.5, 1.0, 2.0, 5.0, 10.0]
zero_rates = [0.042, 0.043, 0.045, 0.048, 0.052, 0.055]

# %%
curve = YieldCurve(
    maturities = maturities,
    zero_rates = zero_rates,
    compounding = "continuous"
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 curve = YieldCurve(
#       2     maturities = maturities,
#       3     zero_rates = zero_rates,
#       4     compounding = "continuous"
#       5     )
#
# NameError: name 'YieldCurve' is not defined

# %%
test_maturities = [0.75, 3.0, 7.0]

for T in test_maturities:
    z = curve.get_zero_rate(T)
    d = curve.get_discount_factor(T)
    print(f"T = {T:.2f} years | zero rate = {z:.2%} | discount factor = {d:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 test_maturities = [0.75, 3.0, 7.0]
#       3 for T in test_maturities:
# ----> 4     z = curve.get_zero_rate(T)
#       5     d = curve.get_discount_factor(T)
#       6     print(f"T = {T:.2f} years | zero rate = {z:.2%} | discount factor = {d:.4f}")
#
# NameError: name 'curve' is not defined

# %%
# plot 
curve.plot(max_maturity = 10)
